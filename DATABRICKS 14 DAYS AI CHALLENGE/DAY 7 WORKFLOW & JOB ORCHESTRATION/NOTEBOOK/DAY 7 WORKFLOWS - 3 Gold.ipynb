# %% [markdown]
# ### Gold Notebook

# %%
# Widgets
dbutils.widgets.text(
    "silver_path",
    "/Volumes/workspace/ecommerce/ecommerce_data/delta/silver/events",
    "Silver Delta Path"
)

dbutils.widgets.text(
    "gold_path",
    "/Volumes/workspace/ecommerce/ecommerce_data/delta/gold/events",
    "Gold Delta Path"
)

# Read widget values
silver_path = dbutils.widgets.get("silver_path")
gold_path = dbutils.widgets.get("gold_path")

# Read Silver Delta
gold_df = spark.read.format("delta").load(silver_path)


# gold_df = gold_df.groupBy("event_type").agg(f.count("*").alias("event_count"))

# Write Gold Delta
gold_df.write.format("delta").mode("overwrite").save(gold_path)

# Optional: verify
display(gold_df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
