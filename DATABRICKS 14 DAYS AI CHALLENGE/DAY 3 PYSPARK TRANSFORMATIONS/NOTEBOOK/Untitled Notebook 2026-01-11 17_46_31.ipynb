# %% [markdown]
# ### Import required libraries and functions

# %%
from pyspark.sql import functions as f
from pyspark.sql.window import Window

# %% [markdown]
# ### Load the Datafiles (CSV)

# %%
# Load Ecommerce Sample data
events = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv", header=True, inferSchema=True)

# %% [markdown]
# ### Prints the dataset schema

# %%
# check dataset schema
events.printSchema()
events.show(5)
# Out:
# root
#  |-- event_time: timestamp (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- user_id: integer (nullable = true)
#  |-- user_session: string (nullable = true)
#
# +-------------------+----------+----------+-------------------+--------------------+------+------+---------+--------------------+
# |         event_time|event_type|product_id|        category_id|       category_code| brand| price|  user_id|        user_session|
# +-------------------+----------+----------+-------------------+--------------------+------+------+---------+--------------------+
# |2019-11-01 00:00:00|      view|   1003461|2053013555631882655|electronics.smart...|xiaomi|489.07|520088904|4d3b30da-a5e4-49d...|
# |2019-11-01 00:00:00|      view|   5000088|2053013566100866035|appliances.sewing...|janome|293.65|530496790|8e5f4f83-366c-4f7...|
# |2019-11-01 00:00:01|      view|  17302664|2053013553853497655|                NULL| creed| 28.31|561587266|755422e7-9040-477...|
# |2019-11-01 00:00:01|      view|   3601530|2053013563810775923|appliances.kitche...|    lg|712.87|518085591|3bfb58cd-7892-48c...|
# |2019-11-01 00:00:01|      view|   1004775|2053013555631882655|electronics.smart...|xiaomi|183.27|558856683|313628f1-68b8-460...|
# +-------------------+----------+----------+-------------------+--------------------+------+------+---------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### Ensure Correct Data Types for Column

# %%
# spark = SparkSession.builder.appName("ECommerceAnalytics").getOrCreate()

# Ensure numeric types and timestamp
events = events\
.withColumn("price", f.col("price").cast("double")) \
.withColumn("event_time", f.to_timestamp("event_time"))

# %% [markdown]
# ### Extract product_name from category code and filter data

# %%
# Extract product_name from category_code
events = events\
.withColumn(
"product_name",
f.when(f.col("category_code").contains("."), f.split(f.col("category_code"), r"\.")[1])
.otherwise(None)
)

# Filter out rows with no product_name
events_filtered = events.filter(f.col("product_name").isNotNull())

# %% [markdown]
# ### Deduplicate Product Information after Extraction

# %%
products = events_filtered\
.select("product_id","brand") \
.dropDuplicates(["product_id"]) \
.withColumnRenamed("brand", "product_brand")

# %% [markdown]
# ### Perform Joins on Ecommerce Data

# %%
# Join events with product details
events_df = events_filtered.join(products, on="product_id", how="left")
display(events_df.limit(6))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>event_time</th><th>event_type</th><th>category_id</th><th>category_code</th><th>brand</th><th>price</th><th>user_id</th><th>user_session</th><th>product_name</th><th>product_brand</th></tr></thead><tbody><tr><td>1005159</td><td>2019-11-28T04:25:36.000Z</td><td>view</td><td>2053013555631882655</td><td>electronics.smartphone</td><td>xiaomi</td><td>196.27</td><td>577989784</td><td>076fe4e3-6470-4ee8-9818-591dfdbd4d67</td><td>smartphone</td><td>xiaomi</td></tr><tr><td>4900092</td><td>2019-11-09T18:15:37.000Z</td><td>view</td><td>2053013555220840837</td><td>appliances.kitchen.juicer</td><td>zelmer</td><td>32.03</td><td>550957324</td><td>85370975-0300-4192-9e69-f44e9062e8fa</td><td>kitchen</td><td>zelmer</td></tr><tr><td>14701857</td><td>2019-11-08T08:12:45.000Z</td><td>view</td><td>2053013557133443581</td><td>furniture.living_room.cabinet</td><td>null</td><td>116.58</td><td>556645933</td><td>eb8da37b-a581-4bf2-a191-5c4acda8434d</td><td>living_room</td><td>null</td></tr><tr><td>3800548</td><td>2019-11-20T01:53:04.000Z</td><td>view</td><td>2053013566176363511</td><td>appliances.iron</td><td>vitek</td><td>28.29</td><td>550655616</td><td>80c75b9b-5e3c-47b9-a19d-769ad318d78f</td><td>iron</td><td>vitek</td></tr><tr><td>28720794</td><td>2019-11-10T10:23:36.000Z</td><td>view</td><td>2053013565228450757</td><td>apparel.shoes</td><td>baratto</td><td>93.95</td><td>540514959</td><td>76e4342c-8ff0-494b-b36f-07ea85a94643</td><td>shoes</td><td>baratto</td></tr><tr><td>2401349</td><td>2019-11-15T19:54:53.000Z</td><td>view</td><td>2053013563743667055</td><td>appliances.kitchen.hood</td><td>elikor</td><td>169.37</td><td>523893924</td><td>b1b710fc-bd7d-44ff-aff4-c7124fd65fe6</td><td>kitchen</td><td>elikor</td></tr></tbody></table></div>

# %% [markdown]
# ### Calculate Running Totals with Window Functions

# %%
win = Window.partitionBy("user_id").orderBy("event_time") \
.rowsBetween(Window.unboundedPreceding, Window.currentRow)

events_with_cumsum = events_df\
.withColumn(
    "cumulative_events", f.count("*").over(win))\
.withColumn(
    "cumulative_revenue", f.sum(f.when(f.col("event_type")=="purchase", f.col("price")).otherwise(0)).over(win))

display(events_with_cumsum.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>event_time</th><th>event_type</th><th>category_id</th><th>category_code</th><th>brand</th><th>price</th><th>user_id</th><th>user_session</th><th>product_name</th><th>product_brand</th><th>cumulative_events</th><th>cumulative_revenue</th></tr></thead><tbody><tr><td>4804056</td><td>2019-11-14T08:03:01.000Z</td><td>view</td><td>2053013554658804075</td><td>electronics.audio.headphone</td><td>apple</td><td>159.57</td><td>138365902</td><td>39cfa4d2-4120-4b4e-aafa-8bc1d6ac1eb5</td><td>audio</td><td>apple</td><td>1</td><td>0.0</td></tr><tr><td>1201216</td><td>2019-11-11T15:35:53.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>lenovo</td><td>244.25</td><td>153489867</td><td>68c119a9-824d-4fc3-98ad-f86438a8a87c</td><td>tablet</td><td>lenovo</td><td>1</td><td>0.0</td></tr><tr><td>1201471</td><td>2019-11-11T15:54:19.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>samsung</td><td>468.36</td><td>153489867</td><td>4d7ab95d-d685-476b-81bf-1458edbcd083</td><td>tablet</td><td>samsung</td><td>2</td><td>0.0</td></tr><tr><td>1201407</td><td>2019-11-11T15:54:50.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>huawei</td><td>257.12</td><td>153489867</td><td>00c7feef-1944-41d2-a74c-a35c85bdde6f</td><td>tablet</td><td>huawei</td><td>3</td><td>0.0</td></tr><tr><td>1201407</td><td>2019-11-13T14:38:22.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>huawei</td><td>257.12</td><td>153489867</td><td>b8f72e1e-2b88-42ea-948e-32fcfa1690f1</td><td>tablet</td><td>huawei</td><td>4</td><td>0.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Create Derived Features

# %% [markdown]
# #### Top Five Products by Revenue

# %%
revenue = events_with_cumsum \
    .filter(f.col("event_type") == "purchase") \
    .groupBy("product_id", "product_name") \
    .agg(f.round(f.sum("price"), 3).alias("revenue")) \
    .orderBy(f.desc("revenue")) \
    .limit(5)
display(revenue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>revenue</th></tr></thead><tbody><tr><td>1005115</td><td>smartphone</td><td>2.062557432E7</td></tr><tr><td>1005105</td><td>smartphone</td><td>1.144535469E7</td></tr><tr><td>1005135</td><td>smartphone</td><td>7086522.13</td></tr><tr><td>1004249</td><td>smartphone</td><td>6815294.62</td></tr><tr><td>1002544</td><td>smartphone</td><td>5603193.59</td></tr></tbody></table></div>

# %% [markdown]
# #### Running Total per _User_

# %%
win = Window.partitionBy("user_id").orderBy("event_time") \
    .rowsBetween(Window.unboundedPreceding, Window.currentRow)

events_with_cumsum = events_df\
.withColumn(
"cumulative_events", f.count("*").over(win)
)

display(events_with_cumsum.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>event_time</th><th>event_type</th><th>category_id</th><th>category_code</th><th>brand</th><th>price</th><th>user_id</th><th>user_session</th><th>product_name</th><th>product_brand</th><th>cumulative_events</th></tr></thead><tbody><tr><td>4804056</td><td>2019-11-14T08:03:01.000Z</td><td>view</td><td>2053013554658804075</td><td>electronics.audio.headphone</td><td>apple</td><td>159.57</td><td>138365902</td><td>39cfa4d2-4120-4b4e-aafa-8bc1d6ac1eb5</td><td>audio</td><td>apple</td><td>1</td></tr><tr><td>1201216</td><td>2019-11-11T15:35:53.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>lenovo</td><td>244.25</td><td>153489867</td><td>68c119a9-824d-4fc3-98ad-f86438a8a87c</td><td>tablet</td><td>lenovo</td><td>1</td></tr><tr><td>1201471</td><td>2019-11-11T15:54:19.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>samsung</td><td>468.36</td><td>153489867</td><td>4d7ab95d-d685-476b-81bf-1458edbcd083</td><td>tablet</td><td>samsung</td><td>2</td></tr><tr><td>1201407</td><td>2019-11-11T15:54:50.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>huawei</td><td>257.12</td><td>153489867</td><td>00c7feef-1944-41d2-a74c-a35c85bdde6f</td><td>tablet</td><td>huawei</td><td>3</td></tr><tr><td>1201407</td><td>2019-11-13T14:38:22.000Z</td><td>view</td><td>2172371436436455782</td><td>electronics.tablet</td><td>huawei</td><td>257.12</td><td>153489867</td><td>b8f72e1e-2b88-42ea-948e-32fcfa1690f1</td><td>tablet</td><td>huawei</td><td>4</td></tr></tbody></table></div>

# %% [markdown]
# #### Conversion Rate by Category

# %%
conversion = events_df\
.groupBy("category_code") \
.pivot("event_type", ["view", "purchase"]) \
.count() \
.withColumn(
    "conversion_rate",
    f.round((f.col("purchase") / f.col("view")) * 100, 3)
    )

display(conversion)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>category_code</th><th>view</th><th>purchase</th><th>conversion_rate</th></tr></thead><tbody><tr><td>furniture.living_room.sofa</td><td>417428</td><td>1562</td><td>0.374</td></tr><tr><td>apparel.jumper</td><td>31269</td><td>82</td><td>0.262</td></tr><tr><td>stationery.cartrige</td><td>11943</td><td>191</td><td>1.599</td></tr><tr><td>sport.bicycle</td><td>106037</td><td>536</td><td>0.505</td></tr><tr><td>apparel.sock</td><td>3455</td><td>19</td><td>0.55</td></tr><tr><td>appliances.environment.fan</td><td>3316</td><td>32</td><td>0.965</td></tr><tr><td>kids.swing</td><td>57430</td><td>482</td><td>0.839